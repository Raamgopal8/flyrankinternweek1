# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Raamgopal8/flyrankinternweek1/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# One row represents one content page during one reporting period, with the intended grain of (URL, time period). I will first verify whether this grain is unique and inspect the actual minimum and maximum dates before fixing the final analysis window. The model will use historical observations to generate features and a subsequent 30-day period as the proxy outcome.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# Features include historical clicks, impressions, CTR, average position, engagement, content age, content type, and derived trend features. The label is future performance change, such as future 30-day click change. URL and date are contextual identifiers rather than direct ML features. Future metrics and post-intervention outcomes are excluded because they would create leakage or would not be available at scoring time.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# I will verify the data contract using queries for (URL, period) uniqueness, row and page counts, actual date range, observations per page, missing values, and availability of historical and future windows. No claim about the dataset's grain, coverage, or completeness will be made until these checks pass.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
#
# The data cannot establish that refreshing content causes improved performance. Page histories may be unbalanced, some early observations may have only GSC fields, and rolling historical/target windows may overlap. Therefore, the model will be evaluated with time-aware validation and interpreted as a prioritization system rather than a causal model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
