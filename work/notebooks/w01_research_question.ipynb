# %% [markdown]
# <a href="https://colab.research.google.com/github/Raamgopal8/flyrankinternweek1/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Raamgopal8/flyrankinternweek1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# ### Lane: Refresh / Content Opportunity Scoring
#
# My problem is to build a content opportunity scoring system that identifies pages whose performance is changing and prioritizes what should be done next.
#
# Instead of asking:<br>
# <u> "Which pages are performing badly?" </u>
#
# I want to answer the more useful question:
#
# <u>"Which pages are worth taking action on now, what action should we take, and why?" </u>
#
# I chose it because it combines: <br>
# <b>Data → ML → ranking → explanation → business action</b> <br>
# rather than stopping at prediction.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ### The core question ? <br>
# Which content pages should we prioritize for intervention, what action should we take, and how confident are we that the intervention is worthwhile?
# The decision is therefore not simply whether a page is good or bad.
# It is: Given limited content-team resources, which page deserves attention first? <br>
#
# ###Cost of a wrong call
#
# This is an important part of the problem.<br> <b>False positive: </b> <u>The model says: "Refresh this page." But the page did not actually need intervention.</u> <br>
# <b> Cost:</b> writer/editor time, engineering/SEO effort, unnecessary content changes,possibility of damaging a page that was already performing well
#
# <b>False negative: </b> <u>The model says:"Monitor this page."But the page was actually an important declining opportunity.</u><br>
# <b>Cost:</b> continued traffic loss, lost clicks, lost potential conversions, delayed recovery, opportunity cost, So the model should not optimize only for classification accuracy. It should optimize for prioritization quality and business impact.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# ### Real number 1 — CTR
#
# CTR = Impressions / Clicks​
#
# So if a page receives:
# 10,000 impressions & 500 clicks <br>
# then:
# CTR = 10000 / 500 = 5%
#
# Google Search Console directly reports clicks, impressions, CTR and average position at the page/query level.
#
# ### Real number 2  — content freshness research <br>
# A recent Ahrefs analysis reported that <u> URLs cited by AI assistants were 25.7% </u> fresher on average than URLs appearing in organic Google results.

# %%
import pandas as pd

df = pd.read_csv("mnist_test.csv")

# 1. Number of pages
num_pages = df["url"].nunique()

# 2. Click change
df["click_change_pct"] = (
    (df["clicks_current"] - df["clicks_previous"])
    / df["clicks_previous"].replace(0, pd.NA)
) * 100

# 3. Percentage of pages with declining clicks
declining_pages = (df["click_change_pct"] < 0).mean() * 100

print(f"Number of pages: {num_pages:,}")
print(f"Pages with declining clicks: {declining_pages:.1f}%")
print(
    f"Median click change: "
    f"{df['click_change_pct'].median():.1f}%"
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1489/1134780125.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("mnist_test.csv")
#       4
#       5 # 1. Number of pages
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# ### I can claim:
#
# <i> "The model identifies pages whose historical performance patterns make them higher-priority candidates for review."
# </i>
# ### I can also say:
#
# <i> "The model finds associations between page-level performance signals and historical content outcomes." </i>
#
# And: <br>
# "The opportunity score is intended to prioritize human review and content actions."
# These are defensible because the model is working from observed historical signals.<br>
# ### I cannot say:
#
# "Refreshing this page will increase its Google ranking." <br>
# "The model knows why Google ranked the page lower."<br>
# "Old content always performs worse."<br>
# "The model automatically decides what content should be deleted."
#
# Why? <br>
# Because the model is observational unless you run a proper experiment.
# Google's ranking systems use many systems and signals, and Google itself emphasizes helpful, reliable, people-first content rather than treating one isolated factor as determinative.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
